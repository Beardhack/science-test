# %% [markdown]
# # 03 Unmeasured-Confounding Workbench
#
# Run hdPS/proxy adjustment, negative controls, QBA, validation examples, IV screening, and the full report generator.

# %%
from src.reporting import run_analysis

result = run_analysis('../config/research_question.yaml', '../reports')
result['credibility_grade']
